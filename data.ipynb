# %% [markdown]
# # Real Data

# %%
from fooof import FOOOF
from fooof.utils.download import load_fooof_data

# %%
import seaborn as sns
sns.set_context('poster')

# %% [markdown]
# ## Settings

# %%
# Set the frequency range to fit the model
freq_range = [2, 40]

# %%
# Notebook settings
SAVE_FIG = False

# %% [markdown]
# ## Real Data Model Plot

# %%
# Download example data files needed for this example
freqs = load_fooof_data('freqs.npy', folder='data')
spectrum = load_fooof_data('spectrum.npy', folder='data')

# %%
# Initialize a FOOOF object
fm = FOOOF(verbose=False)

# Report: fit the model, print the resulting parameters, and plot the reconstruction
fm.fit(freqs, spectrum, freq_range)

# %%
# Plot the model
fm.plot(data_kwargs={'lw' : 4}, aperiodic_kwargs={'lw' : 4}, model_kwargs={'lw' : 4},
        save_fig=SAVE_FIG, file_name='fooof-2peaks.pdf')
